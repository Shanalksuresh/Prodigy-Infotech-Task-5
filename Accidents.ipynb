# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\Prodigy Info-tech\\Task -5\\accidents.csv")
df
# Out:
# C:\Users\shanal\AppData\Local\Temp\ipykernel_19088\1935438812.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("D:\\Prodigy Info-tech\\Task -5\\accidents.csv")
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       200501BS00001               525680.0                178240.0
# 1       200501BS00002               524170.0                181650.0
# 2       200501BS00003               524520.0                182240.0
# 3       200501BS00004               526900.0                177530.0
# 4       200501BS00005               528060.0                179040.0
# ...               ...                    ...                     ...
# 570006       2.01E+12               322650.0                566300.0
# 570007       2.01E+12               323710.0                566150.0
# 570008       2.01E+12               336900.0                586230.0
# ...

# %%
df.shape
# Out:
# (570011, 33)

# %%
df.describe()
# Out:
#        Location_Easting_OSGR  Location_Northing_OSGR      Longitude  \
# count          569910.000000            5.699100e+05  569910.000000
# mean           435609.680423            3.017252e+05      -1.494988
# std             95639.717128            1.613470e+05       1.406187
# min             64980.000000            1.052000e+04      -7.515933
# 25%            371020.000000            1.787400e+05      -2.434639
# 50%            435490.000000            2.773850e+05      -1.470388
# 75%            519230.000000            3.982800e+05      -0.267764
# max            655290.000000            1.208800e+06       1.758337
#
#             Latitude   Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  569910.000000  570011.000000      570011.000000       570011.000000
# mean       52.603655      31.205219           2.839647            1.840773
# std         1.452752      25.516761           0.405771            0.722930
# ...

# %%
# selected columns for analyse
df1 = ['Weather_Conditions','Road_Surface_Conditions','Special_Conditions_at_Site','Urban_or_rural_Aea','Time']
selected_data = df[df1].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 # selected columns for analyse
#       2 df1 = ['Weather_Conditions','Road_Surface_Conditions','Special_Conditions_at_Site','Urban_or_rural_Aea','Time']
# ----> 3 selected_data = df[df1].copy()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# selected columns for analyse
df1 = ['Weather_Conditions','Road_Surface_Conditions','Special_Conditions_at_Site','Urban_or_Rural_Area','Time']
selected_data = df[df1].copy()

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Weather_Conditions', data=selected_data)
plt.title('Accident Counts by Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Road_Surface_Conditions', data=selected_data)
plt.title('Accident Counts by Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()

# %%
# conver 'Time' column to datatime format
df['Time'] =pd.to_datetime(df['Time'])

# extract hour information from the 'Time' column
df['Hour'] = df['Time'].dt.hour

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Hour', data=df)
plt.title('Accident Counts by Time of Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Special_Conditions_at_Site', data=selected_data)
plt.title('Accident Counts by Special Conditions at Site')
plt.xlabel('Special Conditions at Site')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Urban_or_Rural_Area', data=selected_data)
plt.title('Accident Counts by Urban or Rural Area')
plt.xlabel('Urban or Rural Area')
plt.ylabel('Accident Count')
plt.xticks(rotation=45)
plt.show()
